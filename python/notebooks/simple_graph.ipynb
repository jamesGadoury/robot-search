# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import robotsearch
import pathgraph

# %%
graph = pathgraph.dumb_graph("directed")
graph.as_graphviz("dumb_graph")

# %%
f"Shortest path from Start to End: {','.join(robotsearch.dijkstra_search(graph=graph, start='Start', target='End'))}"
# Out:
# 'Shortest path from Start to End: C,D,End'
