# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import robotsearch
import pathgraph

# %%
graph = pathgraph.random_graph(vertexCount=10, pathCount=20, minCost=1, maxCost=5)

# %%
graph.as_graphviz("random_graph")

# %%
print(robotsearch.dijkstra_search_and_display_string(graph=graph, start='3', target='9'))
# Out:
# Shortest path from 3 to 9:
# Steps: 0,2,9
# Cost: 4

# %%
print(robotsearch.dijkstra_search_and_display_string(graph=graph, start='9', target='5'))
# Out:
# Shortest path from 9 to 5:
# Steps: 2,5
# Cost: 4

# %%
# Cool, let's try a directed map now
directedGraph = pathgraph.random_graph(vertexCount=15, pathCount=40, minCost=1, maxCost=5, type="directed")

# %%
directedGraph.as_graphviz("directed_random_graph")

# %%
print(robotsearch.dijkstra_search_and_display_string(graph=directedGraph, start='12', target='2'))
# Out:
# Shortest path from 12 to 2:
# Steps: 10,13,14,1,2
# Cost: 19

# %%
print(robotsearch.dijkstra_search_and_display_string(graph=directedGraph, start='10', target='12'))
# Out:
# Shortest path from 10 to 12:
# Steps: 13,12
# Cost: 3
