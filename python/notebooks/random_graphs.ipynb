# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import robotsearch
import pathgraph

# %%
graph = pathgraph.random_graph(vertexCount=10, pathCount=20, minCost=1, maxCost=5)

# %%
graph.as_graphviz("random_graph")

# %%
robotsearch.dijkstra_search_and_display_string(graph=graph, start='3', target='9')
# Out:
# 'Shortest path from 3 to 9 is 1,9'

# %%
robotsearch.dijkstra_search_and_display_string(graph=graph, start='9', target='5')
# Out:
# 'Shortest path from 9 to 5 is 1,3,5'

# %%
# Cool, let's try a directed map now
directedGraph = pathgraph.random_graph(vertexCount=15, pathCount=40, minCost=1, maxCost=5, type="directed")

# %%
directedGraph.as_graphviz("directed_random_graph")

# %%
robotsearch.dijkstra_search_and_display_string(graph=directedGraph, start='8', target='13')
# Out:
# 'Shortest path from 8 to 13 is 0,13'

# %%
# should raise error if path is impossible

try:
    robotsearch.dijkstra_search(graph=directedGraph, start='12', target='7')
except Exception:
    print("Path from 12 to 7 is impossible")
# Out:
# Path from 12 to 7 is impossible
